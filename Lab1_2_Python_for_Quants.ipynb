# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandrustancluj/2026/blob/main/Lab1_2_Python_for_Quants.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logotypy_ang.jpg](data:image/jpeg;base64,...)
# # Laboratory 1-2

# %% [markdown]
# **Problem 1.** Given two real numbers, $A$ and $B$, compute and display their sum $S$, difference $D$, product $P$, and quotient $C$.
#
# ![p1l1.png](data:image/png;base64,...)

# %%
# write your code here

# %% [markdown]
# **Problem 2.** Given three natural numbers, $A$, $B$, and $C$, compute their arithmetic mean $AM$, geometric mean $GM$, and harmonic mean $HM$.
#
# * $AM = \frac{A+B+C}{3}$
# * $GM = \sqrt[3]{A\cdot B\cdot C} = (A\cdot B\cdot C)^\frac{1}{3}$
# * $HM = \frac{3}{\frac{1}{A}+\frac{1}{B}+\frac{1}{C}}$, where $A$, $B$, and $C$ are nonzero.
#
# ![p2l1.png](data:image/png;base64,...)

# %%
# write your code here

# %% [markdown]
# **Problem 3.** Let $f:\mathbb{R}\times\mathbb{R}\rightarrow\mathbb{R}$ be defined by
#
# $$
# f(x,y)=
# \begin{cases}
# \frac{1}{x^2+y^2+1}, & x^2+y^2<1 \\
# x+y, & x^2+y^2=1 \\
# \frac{1}{x^2+y^2-1}, & x^2+y^2>1
# \end{cases}
# $$
#
# Compute the value of $f(x,y)$.
#
# ![p3l1.png](data:image/png;base64,...)

# %%
# write your code here

# %% [markdown]
# **Problem 4.** Solve the first-degree equation $AX+B=0$.
#
# ![p4l1.png](data:image/png;base64,...)

# %%
# write your code here

# %% [markdown]
# **Problem 5.** Solve the quadratic equation $AX^2+BX+C=0$.
#
# ![p5l1.png](data:image/png;base64,...)

# %%
#scrie codul tau aici

# %% [markdown]
# ![UMCS - Camps for Quants - Logo_Camps for Quants - logo-01.png](data:image/png;base64,...)![umcs-ang.jpg](data:image/jpeg;base64,...)
